# %%
import yfinance as yahooFinance
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, date

# %%
daily_bitcoin = yahooFinance.download("BTC-USD", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
daily_apple = yahooFinance.download("AAPL", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_appleBefore = yahooFinance.download("AAPL", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
appleDiff = daily_apple['Close'].diff()
appleDiff.dropna(inplace=True)

# %%
daily_bitcoin.index
# Out:
# DatetimeIndex(['2023-09-01', '2023-09-02', '2023-09-03', '2023-09-04',
#                '2023-09-05', '2023-09-06', '2023-09-07', '2023-09-08',
#                '2023-09-09', '2023-09-10',
#                ...
#                '2024-08-22', '2024-08-23', '2024-08-24', '2024-08-25',
#                '2024-08-26', '2024-08-27', '2024-08-28', '2024-08-29',
#                '2024-08-30', '2024-08-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
plt.plot(daily_bitcoin['Close'])

# %%
plt.plot(daily_apple['Close'])

# %%
#https://mayerkrebs.com/relative-strength-index-rsi-in-python/
#RSI
def rsi(closeArray, period=14):
    dayDiff = closeArray.diff()
    dayDiff.dropna(inplace=True)
    diffPos = dayDiff.copy()
    diffNeg = dayDiff.copy()

    diffPos[diffPos<0] = 0
    diffNeg[diffNeg>0] = 0
    avgPos = diffPos.rolling(period).mean()
    avgNeg = diffNeg.rolling(period).mean().abs()

    rsi = 100* avgPos / (avgPos + avgNeg)
    rsi.head(20)
    return rsi

# %%
#https://dayanand-shah.medium.com/exponential-moving-average-and-implementation-with-python-1890d1b880e6
#EMA
##def ema(closeArray, period):
  #  ema = closeArray.ewm(span=period, adjust=False).mean()
   # return ema



    #définition d'un exponential movind average sur un 1d array

def ema(closeArray, period):
    
    ema = np.zeros_like(closeArray)
    
    alpha = 2 /(period + 1)
    
    for i in range(period, len(closeArray)):
        
        if np.isnan(closeArray[i]) :
            
            continue
        
        else:
            
            ema[i] = alpha*closeArray[i] + (1 - alpha)*ema[i-1]
        
        
    ema[ema==0]=np.nan
    
    return ema


    
def PEMA(closeArray,period):
    MA1 = ema(closeArray,period)
    MA2 = ema(MA1,period)
    MA3 = ema(MA2,period)
    MA4 = ema(MA3,period)
    MA5 = ema(MA4,period)
    MA6 = ema(MA5,period)
    MA7 = ema(MA6,period)
    MA8 = ema(MA7,period)
    PEMA = 8*MA1 - 28*MA2 + 56*MA3 -70*MA4 + 56*MA5 - 28*MA6 + 8*MA7 - MA8
    return PEMA

# %%
appleRSI = rsi(daily_apple['Close'])

ax2 = plt.subplot2grid((10,1), (5,0), rowspan = 4, colspan = 1)

# Second chart
# Plot the RSI
ax2.set_title('Relative Strength Index')
ax2.plot(appleRSI, color='orange', linewidth=1)
# Add two horizontal lines, signalling the buy and sell ranges.
# Oversold
ax2.axhline(30, linestyle='--', linewidth=1.5, color='green')
# Overbought
ax2.axhline(70, linestyle='--', linewidth=1.5, color='red')

# %%
applePEMA = PEMA(daily_appleBefore['Close'].to_numpy(), 34)

ax2 = plt.subplot2grid((10,1), (5,0), rowspan = 4, colspan = 1)

# Second chart
# Plot the EMA
ax2.set_title('PEMA')
applePEMADate =  applePEMA[len(applePEMA) - len(daily_apple.index):]
ax2.plot(daily_apple.index, applePEMADate, color='green', linewidth=1)
ax2.plot(daily_apple.index, daily_apple['Close'], color='blue', linewidth=1)

# %%
def pemaSignals(pema):
    deltaPEMA = np.diff(pema)
    
    buySignal = np.zeros_like(deltaPEMA)
    sellSignal = np.zeros_like(deltaPEMA)
    
    for i in range(len(deltaPEMA)):
        if i-2 > 0:
            if deltaPEMA[i - 1] < 0. and deltaPEMA[i] > 0. :
                buySignal[i] = 1
            else:
                   buySignal[i] = np.nan
        else:
            buySignal[i] = np.nan
    
    for i in range(len(deltaPEMA)):
        if i-2 > 0:
            if deltaPEMA[i - 1] > 0. and deltaPEMA[i] < 0. :
                sellSignal[i] = 1
            else:
                   sellSignal[i] = np.nan
        else:
            sellSignal[i] = np.nan
        
    buySignal[len(buySignal)-1] = np.nan
    sellSignal[len(buySignal)-1] = np.nan

    return buySignal, sellSignal

# %%
def moneyMade(buySignals, sellSignals, stockPrices, titre):
    cashAmount = 0
    hasInvested = False
    initialBoughtAction = 0
    stockAmount = 1.

    
    for i in range(len(stockPrices)):
        if not hasInvested:
            if(buySignals[i] == 1):
                hasInvested = True
                initialBoughtAction = stockPrices.iloc[i]
                cashAmount = initialBoughtAction
        
        else:   
            if(buySignals[i] == 1):
                stockAmount = cashAmount/stockPrices.iloc[i]

            if(sellSignals[i] == 1):
                cashAmount = stockAmount*stockPrices.iloc[i]

    profit = 100*(cashAmount / initialBoughtAction - 1)
    buy_and_hold = 100*(stockPrices.iloc[i-1]/stockPrices.iloc[0] - 1)
    print(titre +  ' Profit :', profit, '%')
    print('Acheter action Profit: ', buy_and_hold, '%')
    return

# %%
def pemaResult(daily, dailyBefore, pemaPeriod, titre):
    dailyPemaLong = PEMA(dailyBefore['Close'].to_numpy(), pemaPeriod)
    dailyPema = dailyPemaLong[(len(dailyPemaLong)-1) - len(daily.index):]

    
    #diffPEMA = np.append(np.diff(dailyPema), 0)
    buySignal, sellSignal = pemaSignals(dailyPema)

    dailyPema = dailyPema[0:-1]
    
    fig, ax = plt.subplots(figsize=(11, 6))

    priceArray = daily['Close'].to_numpy()
    lowest_point = np.min(priceArray)
    max_point = np.max(priceArray)
    
 
    ax.plot(daily.index, buySignal*daily['Close'], '*g')
    ax.plot(daily.index, sellSignal*daily['Close'], '*r')
    ax.plot(daily.index, dailyPema, color='purple', linewidth=1)
    ax.plot(daily.index, daily['Close'])


    
    plt.title(titre)
    ax.autoscale_view()
    fig.autofmt_xdate()
    
   # ax.fill_between(daily.index, lowest_point, max_point, where= diffPEMA >= 0, facecolor = 'green', alpha = .2)
   # ax.fill_between(daily.index, lowest_point, max_point, where= diffPEMA < 0, facecolor = 'red', alpha = .2)

    buySignalPd = pd.Series(list(buySignal), index=list(range(0,len(daily.index))))
    sellSignalPd = pd.Series(list(sellSignal), index=list(range(0,len(daily.index))))

    begi = 0
    for i in range(len(daily.index)):
        if(begi == 0):
            if(buySignal[i]==1):
                ax.fill_between(daily.index[0:i], max_point, lowest_point, facecolor = 'green', alpha = .2)
                begi = i
        else:
            if(sellSignal[i] == 1):
                ax.fill_between(daily.index[begi-1:i], max_point, lowest_point, facecolor = 'green', alpha = .2)
                begi = i
                
            if(buySignal[i] ==1):
                ax.fill_between(daily.index[begi-1:i], max_point, lowest_point, facecolor = 'red', alpha = .2)
                begi = i

    
    moneyMade(buySignal, sellSignal, daily['Close'], titre)
    return

# %%
#Yearly
#Apple
daily_apple = yahooFinance.download("AAPL", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_appleBeforePEMA = yahooFinance.download("AAPL", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_apple, daily_appleBeforePEMA, 9, 'Apple PEMA 1 an période de 9 jours')
pemaResult(daily_apple, daily_appleBeforePEMA, 20, 'Apple PEMA 1 an période de 20 jours')
pemaResult(daily_apple, daily_appleBeforePEMA, 34, 'Apple PEMA 1 an période de 34 jours')

#BNO
daily_banqueNationale = yahooFinance.download("NA.TO", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_banqueNationaleBefore = yahooFinance.download("NA.TO", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 9, 'Banque Nationale PEMA 1 an période de 9 jour')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 20, 'Banque Nationale PEMA 1 an période de 20 jours')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 34, 'Banque Nationale PEMA 1 an période de 34 jours')

#FOREX
daily_cadusd = yahooFinance.download("CADUSD=X", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_cadusdBefore = yahooFinance.download("CADUSD=X", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_cadusd, daily_cadusdBefore, 9, 'Forex PEMA 1 an période de 9 jours')
pemaResult(daily_cadusd, daily_cadusdBefore, 20, 'Forex PEMA 1 an période de 20 jours')
pemaResult(daily_cadusd, daily_cadusdBefore, 34, 'Forex PEMA 1 an période de 34 jours')

#SP500
daily_sp500 = yahooFinance.download("^GSPC", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_sp500Before = yahooFinance.download("^GSPC", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_sp500, daily_sp500Before, 9, 'SPX PEMA 1 an période de 9 jours')
pemaResult(daily_sp500, daily_sp500Before, 20, 'SPX PEMA 1 an période de 20 jours')
pemaResult(daily_sp500, daily_sp500Before, 34, 'SPX PEMA 1 an période de 34 jours')


#ubi
daily_ubi = yahooFinance.download("UBI.PA", start = datetime(2023,9,1), end = datetime(2024,9,1), interval = '1d')
daily_ubiBefore = yahooFinance.download("UBI.PA", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_ubi, daily_ubiBefore, 9, 'Ubisoft PEMA 1 an période de 9 jours')
pemaResult(daily_ubi, daily_ubiBefore, 20, 'Ubisoft PEMA 1 an période de 20 jours')
pemaResult(daily_ubi, daily_ubiBefore, 34, 'Ubisoft PEMA 1 an période de 34 jours')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Apple PEMA 1 an période de 9 jours Profit : 15.248547803555002 %
# Acheter action Profit:  21.286807317163326 %
# Apple PEMA 1 an période de 20 jours Profit : 25.335095169982402 %
# Acheter action Profit:  21.286807317163326 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Apple PEMA 1 an période de 34 jours Profit : 14.555089967549772 %
# Acheter action Profit:  21.286807317163326 %
# Banque Nationale PEMA 1 an période de 9 jour Profit : 26.856459619910034 %
# Acheter action Profit:  30.691403445980825 %
# Banque Nationale PEMA 1 an période de 20 jours Profit : 30.657825531684658 %
# Acheter action Profit:  30.691403445980825 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Banque Nationale PEMA 1 an période de 34 jours Profit : 8.527319002946943 %
# Acheter action Profit:  30.691403445980825 %
# Forex PEMA 1 an période de 9 jours Profit : -0.2258325300575459 %
# Acheter action Profit:  0.24263518625704528 %
# Forex PEMA 1 an période de 20 jours Profit : -2.6357813512926875 %
# Acheter action Profit:  0.24263518625704528 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Forex PEMA 1 an période de 34 jours Profit : -3.928078421081671 %
# Acheter action Profit:  0.24263518625704528 %
# SPX PEMA 1 an période de 9 jours Profit : 17.10238836079345 %
# Acheter action Profit:  23.83181465733637 %
# SPX PEMA 1 an période de 20 jours Profit : 19.763622407932747 %
# Acheter action Profit:  23.83181465733637 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SPX PEMA 1 an période de 34 jours Profit : 18.693499508500167 %
# Acheter action Profit:  23.83181465733637 %
# Ubisoft PEMA 1 an période de 9 jours Profit : -19.35837712414843 %
# Acheter action Profit:  -40.53447986471242 %
# Ubisoft PEMA 1 an période de 20 jours Profit : -9.328582966808508 %
# Acheter action Profit:  -40.53447986471242 %
# Ubisoft PEMA 1 an période de 34 jours Profit : -32.277775543618304 %
# Acheter action Profit:  -40.53447986471242 %

# %%
#3 mois
#Apple
daily_apple = yahooFinance.download("AAPL", start = datetime(2024,6,1), end = datetime(2024,9,1), interval = '1d')
daily_appleBeforePEMA = yahooFinance.download("AAPL", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_apple, daily_appleBeforePEMA, 9, 'Apple PEMA 3 mois période de 9 jours')
pemaResult(daily_apple, daily_appleBeforePEMA, 20, 'Apple PEMA 3 mois période de 20 jours')
pemaResult(daily_apple, daily_appleBeforePEMA, 34, 'Apple PEMA 3 mois période de 34 jours')

#BNO
daily_banqueNationale = yahooFinance.download("NA.TO", start = datetime(2024,6,1), end = datetime(2024,9,1), interval = '1d')
daily_banqueNationaleBefore = yahooFinance.download("NA.TO", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 9, 'Banque Nationale PEMA 3 mois période de 9 jour')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 20, 'Banque Nationale PEMA 3 mois période de 20 jours')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 34, 'Banque Nationale PEMA 3 mois période de 34 jours')

#FOREX
daily_cadusd = yahooFinance.download("CADUSD=X", start = datetime(2024,6,1), end = datetime(2024,9,1), interval = '1d')
daily_cadusdBefore = yahooFinance.download("CADUSD=X", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_cadusd, daily_cadusdBefore, 9, 'Forex PEMA 3 mois période de 9 jours')
pemaResult(daily_cadusd, daily_cadusdBefore, 20, 'Forex PEMA 3 mois période de 20 jours')
pemaResult(daily_cadusd, daily_cadusdBefore, 34, 'Forex PEMA 3 mois période de 34 jours')

#SP500
daily_sp500 = yahooFinance.download("^GSPC", start = datetime(2024,6,1), end = datetime(2024,9,1), interval = '1d')
daily_sp500Before = yahooFinance.download("^GSPC", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_sp500, daily_sp500Before, 9, 'SPX PEMA 3 mois période de 9 jours')
pemaResult(daily_sp500, daily_sp500Before, 20, 'SPX PEMA 3 mois période de 20 jours')
pemaResult(daily_sp500, daily_sp500Before, 34, 'SPX PEMA 3 mois période de 34 jours')



#ubi
daily_ubi = yahooFinance.download("UBI.PA", start = datetime(2024,6,1), end = datetime(2024,9,1), interval = '1d')
daily_ubiBefore = yahooFinance.download("UBI.PA", start = datetime(2023,1,1), end = datetime(2024,9,1), interval = '1d')

pemaResult(daily_ubi, daily_ubiBefore, 9, 'Ubisoft PEMA 3 mois période de 9 jours')
pemaResult(daily_ubi, daily_ubiBefore, 20, 'Ubisoft PEMA 3 mois période de 20 jours')
pemaResult(daily_ubi, daily_ubiBefore, 34, 'Ubisoft PEMA 3 mois période de 34 jours')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Apple PEMA 3 mois période de 9 jours Profit : 3.9777331576621666 %
# Acheter action Profit:  18.430136953982988 %
# Apple PEMA 3 mois période de 20 jours Profit : 6.648266108904566 %
# Acheter action Profit:  18.430136953982988 %
# Apple PEMA 3 mois période de 34 jours Profit : 4.904374541202228 %
# Acheter action Profit:  18.430136953982988 %
# Banque Nationale PEMA 3 mois période de 9 jour Profit : 8.76249784824521 %
# Acheter action Profit:  5.802050536537839 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Banque Nationale PEMA 3 mois période de 20 jours Profit : 10.822100762467946 %
# Acheter action Profit:  5.802050536537839 %
# Banque Nationale PEMA 3 mois période de 34 jours Profit : 2.7410738664220613 %
# Acheter action Profit:  5.802050536537839 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Forex PEMA 3 mois période de 9 jours Profit : 0.05021675165615136 %
# Acheter action Profit:  1.0528961238872814 %
# Forex PEMA 3 mois période de 20 jours Profit : -0.6259350667107588 %
# Acheter action Profit:  1.0528961238872814 %
# Forex PEMA 3 mois période de 34 jours Profit : -0.7050964942070026 %
# Acheter action Profit:  1.0528961238872814 %
# SPX PEMA 3 mois période de 9 jours Profit : 2.5869608586770676 %
# Acheter action Profit:  5.840179889787844 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SPX PEMA 3 mois période de 20 jours Profit : 2.9526082978088786 %
# Acheter action Profit:  5.840179889787844 %
# SPX PEMA 3 mois période de 34 jours Profit : 5.012421502475539 %
# Acheter action Profit:  5.840179889787844 %
# Ubisoft PEMA 3 mois période de 9 jours Profit : -11.08703166050623 %
# Acheter action Profit:  -24.92380777213452 %
# Ubisoft PEMA 3 mois période de 20 jours Profit : -0.4817885578936476 %
# Acheter action Profit:  -24.92380777213452 %
# Ubisoft PEMA 3 mois période de 34 jours Profit : -8.608493855008758 %
# Acheter action Profit:  -24.92380777213452 %

# %%
#1 mois
#Apple
daily_apple = yahooFinance.download("AAPL", start = datetime(2024,8,1), end = datetime(2024,9,1), interval = '1h')
daily_appleBeforePEMA = yahooFinance.download("AAPL", start = datetime(2024,7,10), end = datetime(2024,9,1), interval = '1h')

pemaResult(daily_apple, daily_appleBeforePEMA, 9, 'Apple PEMA 1 mois période 9 heures')
pemaResult(daily_apple, daily_appleBeforePEMA, 20, 'Apple PEMA 1 mois période 20 heures')
pemaResult(daily_apple, daily_appleBeforePEMA, 34, 'Apple PEMA 1 mois période 34 heures')

#BNO
daily_banqueNationale = yahooFinance.download("NA.TO", start = datetime(2024,8,1), end = datetime(2024,9,1), interval = '1h')
daily_banqueNationaleBefore = yahooFinance.download("NA.TO", start = datetime(2024,7,10), end = datetime(2024,9,1), interval = '1h')

pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 9, 'Banque Nationale 1 mois PEMA période 9 heures')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 20, 'Banque Nationale 1 mois PEMA période 20 heures')
pemaResult(daily_banqueNationale, daily_banqueNationaleBefore, 34, 'Banque Nationale 1 mois PEMA période 34 heures')

#FOREX
daily_cadusd = yahooFinance.download("CADUSD=X", start = datetime(2024,8,1), end = datetime(2024,9,1), interval = '1h')
daily_cadusdBefore = yahooFinance.download("CADUSD=X", start = datetime(2024,7,10), end = datetime(2024,9,1), interval = '1h')

pemaResult(daily_cadusd, daily_cadusdBefore, 9, 'Forex PEMA 1 mois période 9 heures')
pemaResult(daily_cadusd, daily_cadusdBefore, 20, 'Forex PEMA 1 mois période 20 heures')
pemaResult(daily_cadusd, daily_cadusdBefore, 34, 'Forex PEMA 1 mois période 34 heures')

#SP500
daily_sp500 = yahooFinance.download("^GSPC", start = datetime(2024,8,1), end = datetime(2024,9,1), interval = '1h')
daily_sp500Before = yahooFinance.download("^GSPC", start = datetime(2024,7,10), end = datetime(2024,9,1), interval = '1h')

pemaResult(daily_sp500, daily_sp500Before, 9, 'SPX PEMA 1 mois période 9 heures')
pemaResult(daily_sp500, daily_sp500Before, 20, 'SPX PEMA 1 mois pérdiode 20 heures')
pemaResult(daily_sp500, daily_sp500Before, 34, 'SPX PEMA 1 mois période 34 heures')

#ubi
daily_ubi = yahooFinance.download("UBI.PA", start = datetime(2024,8,1), end = datetime(2024,9,1), interval = '1h')
daily_ubiBefore = yahooFinance.download("UBI.PA", start = datetime(2024,7,10), end = datetime(2024,9,1), interval = '1h')

pemaResult(daily_ubi, daily_ubiBefore, 9, 'Ubisoft PEMA 1 mois période de 9 heures')
pemaResult(daily_ubi, daily_ubiBefore, 20, 'Ubisoft PEMA 1 mois période de 20 heures')
pemaResult(daily_ubi, daily_ubiBefore, 34, 'Ubisoft PEMA 1 mois période de 34 heures')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Apple PEMA 1 mois période 9 heures Profit : 0.07003946546362272 %
# Acheter action Profit:  3.506866661986785 %
# Apple PEMA 1 mois période 20 heures Profit : -1.7738893014907942 %
# Acheter action Profit:  3.506866661986785 %
# Apple PEMA 1 mois période 34 heures Profit : -1.3440885610983555 %
# Acheter action Profit:  3.506866661986785 %
# [*********************100%%**********************]  1 of 1 completed
# Banque Nationale 1 mois PEMA période 9 heures Profit : -1.49737939326835 %
# Acheter action Profit:  7.566530435065921 %
# Banque Nationale 1 mois PEMA période 20 heures Profit : 0.9735436636131523 %
# Acheter action Profit:  7.566530435065921 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Banque Nationale 1 mois PEMA période 34 heures Profit : 4.406372786430501 %
# Acheter action Profit:  7.566530435065921 %
# Forex PEMA 1 mois période 9 heures Profit : 1.428688917157639 %
# Acheter action Profit:  2.3337989129124326 %
# Forex PEMA 1 mois période 20 heures Profit : 1.0086181067394895 %
# Acheter action Profit:  2.3337989129124326 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Forex PEMA 1 mois période 34 heures Profit : 1.0192183537900412 %
# Acheter action Profit:  2.3337989129124326 %
# SPX PEMA 1 mois période 9 heures Profit : -1.4768207717317128 %
# Acheter action Profit:  2.020889008453275 %
# SPX PEMA 1 mois pérdiode 20 heures Profit : -3.2909802012247247 %
# Acheter action Profit:  2.020889008453275 %
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# SPX PEMA 1 mois période 34 heures Profit : 0.97911251292504 %
# Acheter action Profit:  2.020889008453275 %
# Ubisoft PEMA 1 mois période de 9 heures Profit : -1.911980556462689 %
# Acheter action Profit:  -7.657287583655236 %
# Ubisoft PEMA 1 mois période de 20 heures Profit : -3.126301770203732 %
# Acheter action Profit:  -7.657287583655236 %
# Ubisoft PEMA 1 mois période de 34 heures Profit : 0.09105513222456008 %
# Acheter action Profit:  -7.657287583655236 %
